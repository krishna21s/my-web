# %% [markdown]
# <a href="https://colab.research.google.com/github/krishna21s/my-web/blob/main/Welcome_To_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://www.dropbox.com/scl/fi/7ibydw80e8fh9sukymf8w/sample3.txt
# Out:
# --2024-03-05 16:25:32--  https://www.dropbox.com/scl/fi/7ibydw80e8fh9sukymf8w/sample3.txt
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sample3.txt’
#
# sample3.txt             [  <=>               ]  71.20K   208KB/s    in 0.3s
#
# 2024-03-05 16:25:33 (208 KB/s) - ‘sample3.txt’ saved [72906]

# %%
f = open("/content/sample3.txt")

# %%
c=[]
for x in f:
  print(x)
  c.append(x.split(' '))

# %%
print(c)
# Out:
# [['<head><meta', 'charset="utf-8"', '/>\n'], ['<meta', 'content="noindex,', 'nofollow,', 'noimageindex"', 'name="robots"', '/>\n'], ['<meta', 'content="width=device-width,', 'initial-scale=1"', 'name="viewport"', '/>\n'], ['<meta', 'content="Shared', 'with', 'Dropbox"', 'property="og:description"', '/>\n'], ['<meta', 'content="Dropbox"', 'property="og:site_name"', '/>\n'], ['<meta', 'content="/scl/fi/7ibydw80e8fh9sukymf8w/sample3.txt"', 'property="og:url"', '/>\n'], ['<meta', 'content="sample3.txt"', 'property="og:title"', '/>\n'], ['<meta', 'content="https://www.dropbox.com/static/metaserver/static/images/opengraph/opengraph-content-icon-file-text-landscape.png"', 'property="og:image"', '/>\n'], ['<meta', 'content="210019893730"', 'property="fb:app_id"', '/>\n'], ['<meta', 'content="160"', 'property="og:image:width"', '/>\n'], ['<meta', 'content="160"', 'property="og:image:height"', '/>\n'], ['<script', 'nonce="m&#43;f4d&#43;WbLjR031JRagrzyrclc8A=">window.EDISON_METRICS_JS_EXECUTION
# ...

# %%
d=0
for i in range(len(c)):
  d+=1
print(f"number of conunted words = {d}")
# Out:
# number of conunted words = 210
